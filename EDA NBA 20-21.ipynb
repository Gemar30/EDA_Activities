# %%
# 2020 - 2021 NBA Season Player stats per game
year = '2021'
str =  "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html"
# Combining the URL + year string together
url = str.format(year)
url
# Out:
# 'https://www.basketball-reference.com/leagues/NBA_2021_per_game.html'

# %% [markdown]
# Return a list of URL given a list of years example (2015, 2016, 2017, 2018, 2019)

# %%
# years = [2015, 2016, 2017, 2018, 2019]
# str =  "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html"

# for year in years:
#     url = str.format(year)
#     print(url)

# %%
url = 'https://www.basketball-reference.com/leagues/NBA_2021_per_game.html'

# %% [markdown]
# Read HTML page into pandas

# %%
import pandas as pd

# %%
# Using pd.read_html() funtion to read HTML webpage
df = pd.read_html(url, header =0) #header = first row as a header
df
# Out:
# [      Rk                    Player    Pos  Age   Tm   G  GS    MP    FG   FGA  \
#  0      1          Precious Achiuwa     PF   21  MIA  61   4  12.1   2.0   3.7
#  1      2              Jaylen Adams     PG   24  MIL   7   0   2.6   0.1   1.1
#  2      3              Steven Adams      C   27  NOP  58  58  27.7   3.3   5.3
#  3      4               Bam Adebayo      C   23  MIA  64  64  33.5   7.1  12.5
#  4      5         LaMarcus Aldridge      C   35  TOT  26  23  25.9   5.4  11.4
#  5      5         LaMarcus Aldridge      C   35  SAS  21  18  25.9   5.5  11.8
#  6      5         LaMarcus Aldridge      C   35  BRK   5   5  26.0   5.0   9.6
#  7      6         Ty-Shon Alexander     SG   22  PHO  15   0   3.1   0.2   0.8
#  8      7  Nickeil Alexander-Walker     SG   22  NOP  46  13  21.9   4.2  10.0
#  9      8             Grayson Allen     SG   25  MEM  50  38  25.2   3.5   8.3
#  10     9             Jarrett Allen      C   22  TOT  63  45  29.6   4.7   7.7
# ...

# %%
# How many tables are there in the webpage
len(df) # number of tables
# Out:
# 1

# %%
# Select the first table
df[0]
# Out:
#       Rk                    Player    Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 0      1          Precious Achiuwa     PF   21  MIA  61   4  12.1   2.0   3.7
# 1      2              Jaylen Adams     PG   24  MIL   7   0   2.6   0.1   1.1
# 2      3              Steven Adams      C   27  NOP  58  58  27.7   3.3   5.3
# 3      4               Bam Adebayo      C   23  MIA  64  64  33.5   7.1  12.5
# 4      5         LaMarcus Aldridge      C   35  TOT  26  23  25.9   5.4  11.4
# 5      5         LaMarcus Aldridge      C   35  SAS  21  18  25.9   5.5  11.8
# 6      5         LaMarcus Aldridge      C   35  BRK   5   5  26.0   5.0   9.6
# 7      6         Ty-Shon Alexander     SG   22  PHO  15   0   3.1   0.2   0.8
# 8      7  Nickeil Alexander-Walker     SG   22  NOP  46  13  21.9   4.2  10.0
# 9      8             Grayson Allen     SG   25  MEM  50  38  25.2   3.5   8.3
# 10     9             Jarrett Allen      C   22  TOT  63  45  29.6   4.7   7.7
# ...

# %%
df2021 = df[0]

# %% [markdown]
# Data Cleaning

# %%
df2021[df2021.Age == 'Age']
# Out:
#      Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB  \
# 28   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 51   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 76   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 106  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 132  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 163  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 190  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 213  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 238  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 269  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 300  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# ...

# %%
len(df2021[df2021.Age == 'Age'])
# Out:
# 26

# %%
df = df2021.drop(df2021[df2021.Age == 'Age'].index)

# %%
df.shape
# Out:
# (705, 30)

# %%
df.shape
# Out:
# (705, 30)

# %% [markdown]
# EDA

# %%
df2021 = df

# %%
df2021.shape
# Out:
# (705, 30)

# %%
# Check for missing values
df2021.isnull().sum()
# Out:
# Rk         0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%        2
# 3P         0
# 3PA        0
# 3P%       35
# 2P         0
# 2PA        0
# 2P%        6
# eFG%       2
# FT         0
# FTA        0
# FT%       29
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# dtype: int64

# %%
df2021.PTS.max()
# Out:
# '9.9'

# %%
df2021 = df2021.drop(['Rk'], axis=1)

# %%
df2021.PTS.max()
# Out:
# '9.9'

# %%
df2021.to_csv('nba2021.csv', index= False)

# %%
ls
# Out:
# EDA NBA 20-21.ipynb      Olympic Data Analysis/   nba2019.csv
# EDA NBA 2019.ipynb       Penguins.ipynb           nba2020.csv
# EDA NBA 2020.ipynb       README.md                nba2021.csv
# EDA Using Python.ipynb   StudentsPerformance.csv  penguins_cleaned.csv
# EDASample.ipynb          airlines_data_part.csv

# %%
df_2021 = pd.read_csv('nba2021.csv')

# %%
df_2021.PTS.max()
# Out:
# 32.0

# %%
df_2021.dtypes
# Out:
# Player     object
# Pos        object
# Age         int64
# Tm         object
# G           int64
# GS          int64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# dtype: object

# %%
#shows specific data types number in columns
df_2021.select_dtypes(include=['number'])
# Out:
#      Age   G  GS    MP    FG   FGA    FG%   3P   3PA    3P%  ...    FT%  ORB  \
# 0     21  61   4  12.1   2.0   3.7  0.544  0.0   0.0  0.000  ...  0.509  1.2
# 1     24   7   0   2.6   0.1   1.1  0.125  0.0   0.3  0.000  ...    NaN  0.0
# 2     27  58  58  27.7   3.3   5.3  0.614  0.0   0.1  0.000  ...  0.444  3.7
# 3     23  64  64  33.5   7.1  12.5  0.570  0.0   0.1  0.250  ...  0.799  2.2
# 4     35  26  23  25.9   5.4  11.4  0.473  1.2   3.1  0.388  ...  0.872  0.7
# 5     35  21  18  25.9   5.5  11.8  0.464  1.3   3.6  0.360  ...  0.838  0.8
# 6     35   5   5  26.0   5.0   9.6  0.521  0.8   1.0  0.800  ...  1.000  0.4
# 7     22  15   0   3.1   0.2   0.8  0.250  0.1   0.6  0.222  ...  0.500  0.1
# 8     22  46  13  21.9   4.2  10.0  0.419  1.7   4.8  0.347  ...  0.727  0.3
# 9     25  50  38  25.2   3.5   8.3  0.418  2.1   5.5  0.391  ...  0.868  0.4
# 10    22  63  45  29.6   4.7   7.7  0.618  0.1   0.3  0.316  ...  0.703  3.1
# ...

# %%
df_2021.select_dtypes(include=['object'])
# Out:
#                        Player    Pos   Tm
# 0            Precious Achiuwa     PF  MIA
# 1                Jaylen Adams     PG  MIL
# 2                Steven Adams      C  NOP
# 3                 Bam Adebayo      C  MIA
# 4           LaMarcus Aldridge      C  TOT
# 5           LaMarcus Aldridge      C  SAS
# 6           LaMarcus Aldridge      C  BRK
# 7           Ty-Shon Alexander     SG  PHO
# 8    Nickeil Alexander-Walker     SG  NOP
# 9               Grayson Allen     SG  MEM
# 10              Jarrett Allen      C  TOT
# 11              Jarrett Allen      C  BRK
# 12              Jarrett Allen      C  CLE
# 13            Al-Farouq Aminu     PF  TOT
# 14            Al-Farouq Aminu     PF  ORL
# 15            Al-Farouq Aminu     PF  CHI
# 16              Kyle Anderson     PF  MEM
# 17      Giannis Antetokounmpo     PF  MIL
# 18       Kostas Antetokounmpo     PF  LAL
# 19     Thanasis Antetokounmpo     SF  MIL
# 20            Carmelo Anthony     PF  POR
# ...

# %%
# You can back the option to default
pd.set_option('display.max_rows', 10)
df_2021
# Out:
#                 Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0     Precious Achiuwa  PF   21  MIA  61   4  12.1  2.0   3.7  0.544  ...
# 1         Jaylen Adams  PG   24  MIL   7   0   2.6  0.1   1.1  0.125  ...
# 2         Steven Adams   C   27  NOP  58  58  27.7  3.3   5.3  0.614  ...
# 3          Bam Adebayo   C   23  MIA  64  64  33.5  7.1  12.5  0.570  ...
# 4    LaMarcus Aldridge   C   35  TOT  26  23  25.9  5.4  11.4  0.473  ...
# ..                 ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 700       Delon Wright  PG   28  SAC  27   8  25.8  3.9   8.3  0.462  ...
# 701     Thaddeus Young  PF   32  CHI  68  23  24.3  5.4   9.7  0.559  ...
# 702         Trae Young  PG   22  ATL  63  63  33.7  7.7  17.7  0.438  ...
# 703        Cody Zeller   C   28  CHO  48  21  20.9  3.8   6.8  0.559  ...
# 704        Ivica Zubac   C   23  LAC  72  33  22.3  3.6   5.5  0.652  ...
#
#        FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
# Which player scores the most points per game

df_2021[df_2021.PTS==df_2021.PTS.max()]
# Out:
#             Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...    FT%  \
# 151  Stephen Curry  PG   32  GSW  63  63  34.2  10.4  21.7  0.482  ...  0.916
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 151  0.5  5.0  5.5  5.8  1.2  0.1  3.4  1.9  32.0
#
# [1 rows x 29 columns]

# %%
#I assign a variable name PlayerMaxpoints in player scored most points per game
player_max_points = df_2021[df_2021.PTS==df_2021.PTS.max()]

# %%
player_max_points
# Out:
#             Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...    FT%  \
# 151  Stephen Curry  PG   32  GSW  63  63  34.2  10.4  21.7  0.482  ...  0.916
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 151  0.5  5.0  5.5  5.8  1.2  0.1  3.4  1.9  32.0
#
# [1 rows x 29 columns]

# %%
#Name of the team of that player
player_max_points.Tm
# Out:
# 151    GSW
# Name: Tm, dtype: object

# %%
# Position of Player
player_max_points.Pos
# Out:
# 151    PG
# Name: Pos, dtype: object

# %%
#Number of Games played of player
player_max_points.G
# Out:
# 151    63
# Name: G, dtype: int64

# %%
#Player scored more than 20 points
df_2021[df_2021.PTS > 20]
# Out:
#                     Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  \
# 17   Giannis Antetokounmpo  PF   26  MIL  61  61  33.0  10.3  18.0  0.569
# 45            Bradley Beal  SG   27  WAS  60  60  35.8  11.2  23.0  0.485
# 71            Devin Booker  SG   24  PHO  67  67  33.9   9.3  19.2  0.484
# 89         Malcolm Brogdon  PG   28  IND  56  56  34.5   7.9  17.5  0.453
# 94            Jaylen Brown  SG   24  BOS  58  58  34.5   9.3  19.2  0.484
# ..                     ...  ..  ...  ...  ..  ..   ...   ...   ...    ...
# 665              John Wall  PG   30  HOU  40  40  32.2   7.3  18.2  0.404
# 675      Russell Westbrook  PG   32  WAS  65  65  36.4   8.4  19.0  0.439
# 688        Zion Williamson  PF   20  NOP  61  61  33.2  10.4  17.0  0.611
# 696         Christian Wood   C   25  HOU  41  41  32.3   8.0  15.6  0.514
# 702             Trae Young  PG   22  ATL  63  63  33.7   7.7  17.7  0.438
#
#      ...    FT%  ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# ...

# %%
#Highest 3 pts field goal per game
df_2021[df_2021['3P' ]== df_2021['3P'].max()]
# Out:
#             Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...    FT%  \
# 151  Stephen Curry  PG   32  GSW  63  63  34.2  10.4  21.7  0.482  ...  0.916
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 151  0.5  5.0  5.5  5.8  1.2  0.1  3.4  1.9  32.0
#
# [1 rows x 29 columns]

# %%
#Highest Assist per game
df_2021[df_2021['AST']== df_2021['AST'].max()]
# Out:
#                 Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 675  Russell Westbrook  PG   32  WAS  65  65  36.4  8.4  19.0  0.439  ...
#
#        FT%  ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# 675  0.656  1.7  9.9  11.5  11.7  1.4  0.4  4.8  2.9  22.2
#
# [1 rows x 29 columns]

# %%
#Highest total Rebound per game
df_2021[df_2021['TRB']== df_2021['TRB'].max()]
# Out:
#            Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...    FT%  \
# 113  Clint Capela   C   26  ATL  63  63  30.1  6.6  11.0  0.594  ...  0.573
#
#      ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 113  4.7  9.6  14.3  0.8  0.7  2.0  1.2  2.3  15.2
#
# [1 rows x 29 columns]

# %%
#Group by
LAL=df_2021.groupby('Tm').get_group('LAL')
LAL
# Out:
#                        Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  \
# 18       Kostas Antetokounmpo  PF   23  LAL  15   0   3.7  0.2   0.7  0.300
# 108            Devontae Cacok  PF   24  LAL  20   1   4.9  0.9   1.5  0.586
# 109  Kentavious Caldwell-Pope  SG   27  LAL  67  67  28.4  3.3   7.6  0.431
# 120               Alex Caruso  PG   26  LAL  58   6  21.0  2.3   5.3  0.436
# 136                Quinn Cook  PG   27  LAL  16   0   3.9  0.8   1.6  0.462
# ..                        ...  ..  ...  ...  ..  ..   ...  ...   ...    ...
# 423           Wesley Matthews  SG   34  LAL  58  10  19.5  1.5   4.3  0.353
# 437          Alfonzo McKinnie  SF   28  LAL  39   0   6.6  1.2   2.4  0.516
# 441              Ben McLemore  SG   27  LAL  21   1  17.5  2.6   6.7  0.390
# 460           Markieff Morris  PF   31  LAL  61  27  19.7  2.5   6.2  0.405
# 582           Dennis Schröder  SG   27  LAL  61  61  32.1  5.4  12.5  0.437
#
# ...

# %%
#Player scored the highest points in LAL(lakers)
LAL[LAL.PTS == LAL.PTS.max()]
# Out:
#            Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...    FT%  \
# 328  LeBron James  PG   36  LAL  45  45  33.4  9.4  18.3  0.513  ...  0.698
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 328  0.6  7.0  7.7  7.8  1.1  0.6  3.7  1.6  25.0
#
# [1 rows x 29 columns]

# %%
WAS = df_2021.groupby('Tm').get_group('WAS')
WAS
# Out:
#                 Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 28         Deni Avdija  SF   20  WAS  54  32  23.3   2.4   5.8  0.417  ...
# 45        Bradley Beal  SG   27  WAS  60  60  35.8  11.2  23.0  0.485  ...
# 48         Jordan Bell   C   26  WAS   5   1  13.4   1.4   4.0  0.350  ...
# 51       Dāvis Bertāns  PF   28  WAS  57   7  25.7   3.4   8.4  0.404  ...
# 70         Isaac Bonga  SF   21  WAS  40   8  10.8   0.8   2.0  0.370  ...
# ..                 ...  ..  ...  ...  ..  ..   ...   ...   ...    ...  ...
# 563    Jerome Robinson  SG   23  WAS  17   6  17.9   1.6   5.6  0.295  ...
# 600          Ish Smith  PG   32  WAS  44   1  21.0   2.9   6.8  0.434  ...
# 660      Moritz Wagner   C   23  WAS  25  13  15.0   2.5   4.9  0.508  ...
# 675  Russell Westbrook  PG   32  WAS  65  65  36.4   8.4  19.0  0.439  ...
# 694    Cassius Winston  PG   22  WAS  22   0   4.5   0.6   1.5  0.424  ...
#
#        FT%  ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# ...

# %%
WAS[WAS.PTS == WAS.PTS.max()]
# Out:
#           Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...    FT%  \
# 45  Bradley Beal  SG   27  WAS  60  60  35.8  11.2  23.0  0.485  ...  0.889
#
#     ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 45  1.2  3.5  4.7  4.4  1.2  0.4  3.1  2.3  31.3
#
# [1 rows x 29 columns]
