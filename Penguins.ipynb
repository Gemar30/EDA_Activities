# %%
import pandas as pd

# %%
df = pd.read_csv('penguins_cleaned.csv')

# %%
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7                181
# 1       Adelie  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            36.7           19.3                193
# 4       Adelie  Torgersen            39.3           20.6                190
# ..         ...        ...             ...            ...                ...
# 328  Chinstrap      Dream            55.8           19.8                207
# 329  Chinstrap      Dream            43.5           18.1                202
# 330  Chinstrap      Dream            49.6           18.2                193
# 331  Chinstrap      Dream            50.8           19.0                210
# 332  Chinstrap      Dream            50.2           18.7                198
#
#      body_mass_g     sex
# 0           3750    male
# ...

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
# Add missing values to data frame
df.iloc[0, 0] # index location [row, column]
# Out:
# 'Adelie'

# %%
# assign missing value to it
df.iloc[0, 0] = pd.NA # NA is missing values
df.iloc[5, 1] = pd.NA
df.iloc[10, 2] = pd.NA
df.iloc[15, 3] = pd.NA
df.iloc[20, 4] = pd.NA
df.iloc[25, 5] = pd.NA
df.iloc[30, 6] = pd.NA

# %%
df
# Out:
#        species     island bill_length_mm bill_depth_mm flipper_length_mm  \
# 0         <NA>  Torgersen           39.1          18.7               181
# 1       Adelie  Torgersen           39.5          17.4               186
# 2       Adelie  Torgersen           40.3          18.0               195
# 3       Adelie  Torgersen           36.7          19.3               193
# 4       Adelie  Torgersen           39.3          20.6               190
# ..         ...        ...            ...           ...               ...
# 328  Chinstrap      Dream           55.8          19.8               207
# 329  Chinstrap      Dream           43.5          18.1               202
# 330  Chinstrap      Dream           49.6          18.2               193
# 331  Chinstrap      Dream           50.8          19.0               210
# 332  Chinstrap      Dream           50.2          18.7               198
#
#     body_mass_g     sex
# 0          3750    male
# 1          3800  female
# ...

# %%
df.isnull() # Check for missing data
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       True   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False           False          False              False
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 328    False   False           False          False              False
# 329    False   False           False          False              False
# 330    False   False           False          False              False
# 331    False   False           False          False              False
# 332    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# ...

# %%
df.isna() # same for checking missing data
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       True   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False           False          False              False
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 328    False   False           False          False              False
# 329    False   False           False          False              False
# 330    False   False           False          False              False
# 331    False   False           False          False              False
# 332    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# ...

# %%
# display only rows with at least 1 missing value
# axis of 0 = rows, axis of 1 = columns
df[df.isnull().any(axis=1)] # each column will determine if there is a missing value
# Out:
#    species     island bill_length_mm bill_depth_mm flipper_length_mm  \
# 0     <NA>  Torgersen           39.1          18.7               181
# 5   Adelie       <NA>           38.9          17.8               181
# 10  Adelie  Torgersen           <NA>          17.8               185
# 15  Adelie     Biscoe           37.8          <NA>               174
# 20  Adelie     Biscoe           35.3          18.9              <NA>
# 25  Adelie      Dream           39.5          16.7               178
# 30  Adelie      Dream           39.2          21.1               196
#
#    body_mass_g     sex
# 0         3750    male
# 5         3625  female
# 10        3700  female
# 15        3400  female
# 20        3800  female
# 25        <NA>  female
# 30        4150    <NA>

# %%
df.isnull().sum() # specify the summation of missing value out there
# Out:
# species              1
# island               1
# bill_length_mm       1
# bill_depth_mm        1
# flipper_length_mm    1
# body_mass_g          1
# sex                  1
# dtype: int64

# %%
# Drop missing data
df.dropna()
# Out:
#        species     island bill_length_mm bill_depth_mm flipper_length_mm  \
# 1       Adelie  Torgersen           39.5          17.4               186
# 2       Adelie  Torgersen           40.3          18.0               195
# 3       Adelie  Torgersen           36.7          19.3               193
# 4       Adelie  Torgersen           39.3          20.6               190
# 6       Adelie  Torgersen           39.2          19.6               195
# ..         ...        ...            ...           ...               ...
# 328  Chinstrap      Dream           55.8          19.8               207
# 329  Chinstrap      Dream           43.5          18.1               202
# 330  Chinstrap      Dream           49.6          18.2               193
# 331  Chinstrap      Dream           50.8          19.0               210
# 332  Chinstrap      Dream           50.2          18.7               198
#
#     body_mass_g     sex
# 1          3800  female
# 2          3250  female
# ...

# %%
df
# Out:
#        species     island bill_length_mm bill_depth_mm flipper_length_mm  \
# 0         <NA>  Torgersen           39.1          18.7               181
# 1       Adelie  Torgersen           39.5          17.4               186
# 2       Adelie  Torgersen           40.3          18.0               195
# 3       Adelie  Torgersen           36.7          19.3               193
# 4       Adelie  Torgersen           39.3          20.6               190
# ..         ...        ...            ...           ...               ...
# 328  Chinstrap      Dream           55.8          19.8               207
# 329  Chinstrap      Dream           43.5          18.1               202
# 330  Chinstrap      Dream           49.6          18.2               193
# 331  Chinstrap      Dream           50.8          19.0               210
# 332  Chinstrap      Dream           50.2          18.7               198
#
#     body_mass_g     sex
# 0          3750    male
# 1          3800  female
# ...

# %%
# inplace = True - perform the dropping in the original data frame
df.dropna(inplace = True)

# %%
df
# Out:
#        species     island bill_length_mm bill_depth_mm flipper_length_mm  \
# 1       Adelie  Torgersen           39.5          17.4               186
# 2       Adelie  Torgersen           40.3          18.0               195
# 3       Adelie  Torgersen           36.7          19.3               193
# 4       Adelie  Torgersen           39.3          20.6               190
# 6       Adelie  Torgersen           39.2          19.6               195
# ..         ...        ...            ...           ...               ...
# 328  Chinstrap      Dream           55.8          19.8               207
# 329  Chinstrap      Dream           43.5          18.1               202
# 330  Chinstrap      Dream           49.6          18.2               193
# 331  Chinstrap      Dream           50.8          19.0               210
# 332  Chinstrap      Dream           50.2          18.7               198
#
#     body_mass_g     sex
# 1          3800  female
# 2          3250  female
# ...

# %%
# Replace missing data and fill missing data with replacement values
df.fillna(0)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1       Adelie  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            36.7           19.3                193
# 4       Adelie  Torgersen            39.3           20.6                190
# 6       Adelie  Torgersen            39.2           19.6                195
# ..         ...        ...             ...            ...                ...
# 328  Chinstrap      Dream            55.8           19.8                207
# 329  Chinstrap      Dream            43.5           18.1                202
# 330  Chinstrap      Dream            49.6           18.2                193
# 331  Chinstrap      Dream            50.8           19.0                210
# 332  Chinstrap      Dream            50.2           18.7                198
#
#      body_mass_g     sex
# 1           3800  female
# ...

# %%
df.iloc[0, 0] = pd.NA # NA is missing values
df.iloc[5, 1] = pd.NA
df.iloc[10, 2] = pd.NA
df.iloc[15, 3] = pd.NA
df.iloc[20, 4] = pd.NA
df.iloc[25, 5] = pd.NA
df.iloc[30, 6] = pd.NA

# %%
df
# Out:
#        species     island bill_length_mm bill_depth_mm flipper_length_mm  \
# 1         <NA>  Torgersen           39.5          17.4               186
# 2       Adelie  Torgersen           40.3          18.0               195
# 3       Adelie  Torgersen           36.7          19.3               193
# 4       Adelie  Torgersen           39.3          20.6               190
# 6       Adelie  Torgersen           39.2          19.6               195
# ..         ...        ...            ...           ...               ...
# 328  Chinstrap      Dream           55.8          19.8               207
# 329  Chinstrap      Dream           43.5          18.1               202
# 330  Chinstrap      Dream           49.6          18.2               193
# 331  Chinstrap      Dream           50.8          19.0               210
# 332  Chinstrap      Dream           50.2          18.7               198
#
#     body_mass_g     sex
# 1          3800  female
# 2          3250  female
# ...

# %%
df.fillna(0)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1            0  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            36.7           19.3                193
# 4       Adelie  Torgersen            39.3           20.6                190
# 6       Adelie  Torgersen            39.2           19.6                195
# ..         ...        ...             ...            ...                ...
# 328  Chinstrap      Dream            55.8           19.8                207
# 329  Chinstrap      Dream            43.5           18.1                202
# 330  Chinstrap      Dream            49.6           18.2                193
# 331  Chinstrap      Dream            50.8           19.0                210
# 332  Chinstrap      Dream            50.2           18.7                198
#
#      body_mass_g     sex
# 1           3800  female
# ...

# %%
df.species.fillna('-', inplace = True)

# %%
df
# Out:
#        species     island bill_length_mm bill_depth_mm flipper_length_mm  \
# 1            -  Torgersen           39.5          17.4               186
# 2       Adelie  Torgersen           40.3          18.0               195
# 3       Adelie  Torgersen           36.7          19.3               193
# 4       Adelie  Torgersen           39.3          20.6               190
# 6       Adelie  Torgersen           39.2          19.6               195
# ..         ...        ...            ...           ...               ...
# 328  Chinstrap      Dream           55.8          19.8               207
# 329  Chinstrap      Dream           43.5          18.1               202
# 330  Chinstrap      Dream           49.6          18.2               193
# 331  Chinstrap      Dream           50.8          19.0               210
# 332  Chinstrap      Dream           50.2          18.7               198
#
#     body_mass_g     sex
# 1          3800  female
# 2          3250  female
# ...

# %%
df.fillna(df.mean())
# Out:
# /var/folders/2k/d9m5wss10ns5p_njfb46c_qc0000gn/T/ipykernel_4833/634187881.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean())
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1            -  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen            36.7           19.3              193.0
# 4       Adelie  Torgersen            39.3           20.6              190.0
# 6       Adelie  Torgersen            39.2           19.6              195.0
# ..         ...        ...             ...            ...                ...
# 328  Chinstrap      Dream            55.8           19.8              207.0
# ...
